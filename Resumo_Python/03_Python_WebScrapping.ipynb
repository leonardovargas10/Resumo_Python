# %% [markdown]
# > CONSULTAR:
#
#
#
#
#
# https://www.youtube.com/watch?v=aNtzKGTujuA&t=491s&ab_channel=Let%27sData

# %% [markdown]
# # <font color='red' style='font-size: 40px;'>Library  </font>

# %%
import pandas as pd 
import numpy as np
import scipy as sp 
import matplotlib.pyplot as plt
import seaborn as sns 
import plotly.express as px 
import plotly.graph_objects as go
import warnings

# %matplotlib inline
sns.set()
plt.rcParams['font.family'] = 'Arial'
plt.rcParams['font.size'] = '14'
plt.rcParams['figure.figsize'] = [10, 5]
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('display.float_format', lambda x: '%.2f' % x) # Tira os números do formato de Notação Científica
np.set_printoptions(suppress=True) # Tira os números do formato de Notação Científica em Numpy Arrays
warnings.filterwarnings('ignore')
warnings.simplefilter(action='ignore', category=FutureWarning) # Retira Future Warnings

# %% [markdown]
# # <font color='red' style='font-size: 40px;'>1.0 Introduçao   </font>

# %% [markdown]
# ## 1.1) Funcionamento de Requisições na Internet
#
# > 1. Os usuários mandam requisições para um servidor e o servidor nos retorna uma URL.
#
# > 2. Essa conexão é realizada através do protocolo HTTP. Ele define quais são as regras de comunicação na Internet através dos métodos Get ou Post.
#
# <img src = './img1.png' width = '70%'>
#
# ## 1.2) Protocolo HTTP
#
# <img src = './img8.png' width = '70%'>
# <img src = './img9.png' width = '70%'>
#
# ## 1.3) Código de Status
#
# * Os códigos de status são os responsáveis por sabermos se nossa requisição foi ceita ou não.
#
# * Estaremos sempre interessados na Família que começa com o 2, pois é a Família do Sucesso.
#
# <img src = './img10.png' width = '70%'>
# <img src = './img11.png' width = '70%'>

# %% [markdown]
# ## 1.4) O que é WebScrapping?
#
# > 1. Scrapy é a raspagem/extração de dados de páginas Web.
#
# > 2. Através do Web Scrapping, podemos minerar o HTML da página e extrair as informações que desejamos, salvando-as no formato estruturado para trabalharmos em formatos tabulares.
#
# <img src = './img2.png' width = '70%'>

# %% [markdown]
# ## 1.5) O que é HTML e qual sua Estrutura?
#
# <img src = './img101.png' width = '70%'>
# <img src = './img3.png' width = '70%'>
# <img src = './img4.png' width = '70%'>
# <img src = './img5.png' width = '70%'>
# <img src = './img6.png' width = '70%'>
# <img src = './img7.png' width = '70%'>
#
# **HTML** (*HyperText Markup Language*) é uma linguagem de marcação composta por **tags** que deteminam o papel que cada parte do documento vai assumir. As **tags** são formadas pelo seu nome e atributos. Os atributos servem para configurar e também modificar as características padrões de uma **tag**.
#
# ## Estrutura básica
#
# ```html
# <html>
#     <head>
#         <meta charset="utf-8" />
#         <title>Alura Motors</title>
#     </head>
#     <body>
#         <div id="container">
#             <h1>Alura</h1>
#             <h2 class="formato">Cursos de Tecnologia</h2>
#             <p>Você vai estudar, praticar, discutir e aprender.</p>
#             <a href="https://www.alura.com.br/">Clique aqui</a>
#         </div>
#     </body>
# </html>
# ```
#
# ```<html>``` - determina o início do documento.
#
# ```<head>``` - cabeçalho. Contém informações e configurações do documento.
#
# ```<body>``` - é o corpo do documento, onde todo o conteúdo é colocado. Esta é a parte visível em um navegador.
#
# ## Tags mais comuns
#
# ```<div>``` - define uma divisão da página. Pode ser formatada de diversas maneiras.
#
# ```<h1>, <h2>, <h3>, <h4>, <h5>, <h6>``` - marcadores de títulos.
#
# ```<p>``` - marcador de parágrafo.
#
# ```<a>``` - hiperlink.
#
# ```<img>``` - exibição de imagens.
#
# ```<table>``` - definição de tabelas.
#
# ```<ul>, <li>``` - definição de listas.

# %% [markdown]
# ## 1.6) Requests e BeautifulSoup
#
# <img src = './img102.png' width = '70%'>
# <img src = './img103.png' width = '70%'>
#
# ### Os métodos *find()* e *findAll()*
#
# - ### find(tag, attributes, recursive, text, **kwargs)
#
# - ### findAll(tag, attributes, recursive, text, limit, **kwargs)
#
# #### https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find
# #### https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find-all
#
# > **Observação:**
# > - *findAll()* também pode ser utilizado como *find_all()*
#
# - ### *findParent(tag, attributes, text, **kwargs)*
#
# - ### *findParents(tag, attributes, text, limit, **kwargs)*
#
# #### https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find-parents-and-find-parent
#
# > **Observação:**
# > - findParent()* e *findParents()* também podem ser utilizados como *find_parent()* e *find_parents()*, respectivamente.
# ---
# - ### *findNextSibling(tag, attributes, text, **kwargs)*
#
# - ### *findNextSiblings(tag, attributes, text, limit, **kwargs)*
#
# - ### *findPreviousSibling(tag, attributes, text, **kwargs)*
#
# - ### *findPreviousSiblings(tag, attributes, text, limit, **kwargs)*
#
# #### https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find-next-siblings-and-find-next-sibling
# #### https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find-previous-siblings-and-find-previous-sibling
#
# > **Observação:**
# > - *findNextSibling()*, *findNextSiblings()*, *findPreviousSibling()* e *findPreviousSiblings()* também podem ser utilizados como *find_next_sibling()*, *find_next_siblings()*, *find_previous_sibling()* e *find_previous_siblings()*, respectivamente.
# ---
# - ### *findNext(tag, attributes, text, **kwargs)*
#
# - ### *findAllNext(tag, attributes, text, limit, **kwargs)*
#
# - ### *findPrevious(tag, attributes, text, **kwargs)*
#
# - ### *findAllPrevious(tag, attributes, text, limit, **kwargs)*
#
# #### https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find-all-next-and-find-next
# #### https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find-all-previous-and-find-previous
#
# > **Observação:**
# > - *findNext()*, *findAllNext()*, *findPrevious* e *findAllPrevious* também podem ser utilizados como *find_next()*, *find_all_next()*, *find_previous()* e *find_all_previous()*, respectivamente.
#
# <img src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/BeautifulSoup-method.png" width=80%>

# %% [markdown]
# # <font color='red' style='font-size: 40px;'>2.0 WebScrapping G1 </font>

# %% [markdown]
# > CONSULTAR :
#
# https://www.youtube.com/watch?v=42sTntMEn6o&list=PLg3ZPsW_sghSkRacynznQeEs-vminyTQk&ab_channel=WalissonSilva

# %%
import requests
from bs4 import BeautifulSoup

response = requests.get('https://www.walissonsilva.com/') # variável de requisição

print(f'Status Code: {response.status_code}') # Retorna a resposta do código de status
print() 
print('Header')
print(f'Header: {response.headers}') # Retorna o Cabeçalho do site
print()
# print('Content')
# print(f'Content: {response.content}') # Retorna todo o conteúdo do nosso site...podemos abrir com ctrl+u\

response = requests.get('https://g1.globo.com/') # Variável de Requisição

content = response.content # Retorna todo o conteúdo HTML do nosso site...podemos abrir com ctrl+u

site = BeautifulSoup(content, 'html.parser') # Convertendo o conteúdo HTML para um Objeto BeautfulSoup

print(site.prettify()) # Imprime o Site de Forma mais Organizada

# HTML da notícia
noticia = site.find('div', attrs={'class': 'feed-post-body'
}) # Quero a Tag Div que tenha como Atributo uma Classe com o conteúdo 'feed-post-body'
print(noticia)
print()
# Título: div class="feed-post-body-link"
titulo = noticia.find('a', attrs={'class': 'feed-post-link'
}) # Quero a Tag a que tenha como Atributo uma Classe com o conteúdo 'feed-post-link'

print(titulo.text) # Passando o conteúdo do Título para o formato de Texto
print()

# Subtítulo: div class="feed-post-body-resumo"
subtitulo = noticia.find('ul', attrs={'class': 'bstn-relateditems'
}) # Quero a Tag Div que tenha como Atributo uma Classe com o conteúdo 'feed-post-resumo'

print(subtitulo.text)

print()
print()
print()
print('Automatizando a Busca de Informaçoes com BeautifulSoup')

response = requests.get('https://g1.globo.com/') # Variável de Requisição

content = response.content # Retorna todo o conteúdo HTML do nosso site...podemos abrir com ctrl+u

site = BeautifulSoup(content, 'html.parser') # Convertendo o conteúdo HTML para um Objeto BeautfulSoup

# print(site.prettify()) # Imprime o Site de Forma mais Organizada

lista_noticias = []
# HTML da notícia
noticias = site.findAll('div', attrs={'class': 'feed-post-body'}) 
for noticia in noticias:
    # Título
    titulo = noticia.find('a', attrs={'class': 'feed-post-link'}) 
    #print(f'Titulo: {titulo.text}') # Passando o conteúdo do Título para o formato de Texto

    # Link da Notícia
    link = titulo['href']
    #print(f'Link da Notícia: {link}') # Link da Notícia 

    # Subtítulo
    subtitulo = noticia.find('div', attrs={'class': 'feed-post-body-resumo'})
    if (subtitulo):
        #print(f'Subtítulo: {subtitulo.text}')
        lista_noticias.append([titulo.text, subtitulo.text, link])
    else:
        lista_noticias.append([titulo.text, '', link])

print(lista_noticias)

news = pd.DataFrame(data = lista_noticias, columns = ['Titulo', 'Subtitulo', 'Link'])
news 
# news.to_excel('noticias.xlsx', index = False)
# Out:
# Status Code: 200
#
# Header
# Header: {'Age': '0', 'Cache-Control': 'private, no-cache, no-store, max-age=0, must-revalidate', 'Connection': 'keep-alive', 'Content-Encoding': 'br', 'Content-Type': 'text/html; charset=utf-8', 'Date': 'Mon, 05 Dec 2022 02:22:42 GMT', 'Etag': 'W/"11c1d-AU29H6oRSXFumji89uyVl1ppYM4"', 'Server': 'Vercel', 'Strict-Transport-Security': 'max-age=63072000', 'X-Matched-Path': '/', 'X-Powered-By': 'Next.js', 'X-Vercel-Cache': 'MISS', 'X-Vercel-Id': 'gru1::iad1::kht6j-1670206960848-fe52e7e2222b', 'Transfer-Encoding': 'chunked'}
#
# <!DOCTYPE HTML>
# <html lang="pt-br">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="ie=edge,chrome=1" http-equiv="x-ua-compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <script id="CDA_AAS" type="text/javascript">
#    window.cdaaas = window.cdaaas || {};
#   window.cdaaas.SETTINGS = window.cdaaas.SETTINGS || {};
# ...

# %% [markdown]
# # <font color='red' style='font-size: 40px;'>3.0 WebScrapping Airbnb</font>
#
# > CONSULTAR:
#
# https://www.youtube.com/watch?v=YEvoDf2azq0&ab_channel=IuryRosal
#
# https://www.airbnb.com.br/s/Fortaleza-~-CE/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=may&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&query=Fortaleza%20-%20CE&place_id=ChIJL1zB9iFPxwcRqid5ywZnbf0&checkin=2022-05-09&checkout=2022-05-13&source=structured_search_input_header&search_type=autocomplete_click%22

# %%
import requests 
from bs4 import BeautifulSoup
import re

class WebScrapping:
    def __init__(self, url):
        self.url = url 
        self.soup = self.get_html()

    def get_html(self): # Recebe uma URL e retorna o conteúdo da URL em formato de um Objeto BeautifulSoup
        req = requests.get(self.url) # Adquirindo a URL
        soup = BeautifulSoup(req.content, 'html.parser') # Passando o conteúdo da URL de HTML para um Objeto BeautifulSoup()
        return soup 

    def get_rooms(self): # Recebe o Objeto BeautifulSoup e retorna todas div's da classe 'c4mnd7m dir dir-ltr'
        return self.soup.find_all('div', class_ = 'c4mnd7m dir dir-ltr')

    #def get_subtitle(self, room):
        #return room.find('span', class_ = 'f15liw5s s1cjsi4j dir dir-ltr')
    def get_title(self, room):
        return room.find('span', class_ = ' dir dir-ltr')

    def pick_all_rooms(self): # Percorre cada item do get_rooms
        for room in self.get_rooms():
            #subtitle = self.get_subtitle(room)
            title = self.get_title(room)
            print(title)

# %%
#url = 'https://www.airbnb.com.br/s/Fortaleza-~-CE/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_dates%5B%5D=april&flexible_trip_dates%5B%5D=may&flexible_trip_lengths%5B%5D=weekend_trip&date_picker_type=calendar&query=Fortaleza%20-%20CE&place_id=ChIJL1zB9iFPxwcRqid5ywZnbf0&checkin=2022-05-09&checkout=2022-05-13&source=structured_search_input_header&search_type=autocomplete_click%22'
#web_scrapping = WebScrapping(url)
#print(web_scrapping.get_rooms())
#print(web_scrapping.pick_all_rooms())
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %% [markdown]
# # <font color='red' style='font-size: 40px;'>4.0 Web Scrapping Lets Data </font>
#
# > CONSULTAR :
#
# https://www.youtube.com/watch?v=aNtzKGTujuA&t=491s&ab_channel=Let%27sData
#
# <img src = './img100.png' width = '70%'>

# %%
import requests 
from bs4 import BeautifulSoup
import re

# A primeira coisa a se fazer é entender o que queremos extrair e qual sua estrutura
# Para isso, usar o 'Inspecionar' e, no canto superior esquerdo, clicar na setinha com o nome de 'Select an element in the page to inspect it - Ctrl + Shift + C'

cabecalho = {'user-agent':'Mozilla/5.0'} # Uso de um cabeçalho + Navegador para mostrar que nao somos um Robô

resposta = requests.get(
    'https://www.glassdoor.com.br/Sal%C3%A1rios/cientista-de-dados-sal%C3%A1rio-SRCH_KO0,18.htm',
    headers = cabecalho
    ) # Extraçao das informaçoes do HTML da página
soup = resposta.text # Transformaçao das informaçoes para o formato de Texto

site = BeautifulSoup(soup, 'html.parser') # Convertendo o conteúdo HTML para um Objeto BeautfulSoup

# %% [markdown]
# * Buscando informaçoes sobre o ITAÚ

# %%
itau_unibanco = site.find_all('h3', {'data-test':'salaries-list-item-0-employer-name'})
itau_unibanco
# Out:
# [<h3 class="m-0 css-g261rn" data-test="salaries-list-item-0-employer-name"><style data-emotion-css="f3vw95">.css-f3vw95{cursor:pointer;font-size:15px;line-height:24px;color:#1861bf;font-size:inherit;}.css-f3vw95:hover{color:#0c4085;}</style><a class="css-f3vw95 e1aj7ssy3" href="/Salário/Itaú-Unibanco-Itaú-BBA-e-Rede-Cientista-De-Dados-Salários-E10999_D_KO30,48.htm?filter.payPeriod=MONTHLY">Itaú Unibanco (Itaú BBA e Rede)</a></h3>]

# %%
h3 = itau_unibanco[0]
h3
# Out:
# <h3 class="m-0 css-g261rn" data-test="salaries-list-item-0-employer-name"><style data-emotion-css="f3vw95">.css-f3vw95{cursor:pointer;font-size:15px;line-height:24px;color:#1861bf;font-size:inherit;}.css-f3vw95:hover{color:#0c4085;}</style><a class="css-f3vw95 e1aj7ssy3" href="/Salário/Itaú-Unibanco-Itaú-BBA-e-Rede-Cientista-De-Dados-Salários-E10999_D_KO30,48.htm?filter.payPeriod=MONTHLY">Itaú Unibanco (Itaú BBA e Rede)</a></h3>

# %%
h3.contents[1].text # Acessando as estruturas Filho
# Out:
# 'Itaú Unibanco (Itaú BBA e Rede)'

# %% [markdown]
# * Buscando Informaçoes sobre muitas Empresas

# %%
lista_empresas = site.find_all(
    'h3', 
    {'data-test':re.compile('salaries-list-item-.*-employer-name')} # Busca todas as estruturas
    )

lista_salarios = site.find_all(
    'div', 
    {'data-test':re.compile('salaries-list-item-.*-salary-info')}
)

empresas = []
salarios = []
for empresa, salario in zip(lista_empresas, lista_salarios):
    empresas.append(empresa.find('a').text)
    salarios.append(salario.find('h3').text.replace('R$\xa0', ''))

df = pd.DataFrame(
    {
        'empresa':empresas,
        'salario':salarios
    },
    columns = ['empresa', 'salario']
)
df
# Out:
#                                empresa salario
# 0      Itaú Unibanco (Itaú BBA e Rede)  10.346
# 1                                  IBM   5.748
# 2                             Semantix   8.887
# 3   Hospital Israelita Albert Einstein  12.869
# 4                       Banco Bradesco   7.375
# 5                                Propz   7.170
# 6          Radix Engenharia e Software   8.139
# 7                            Stefanini   7.025
# 8                    Autônomo (Brazil)   6.063
# 9                                TOTVS  11.490
# 10                            Softplan  10.566
# 11                              Nubank  12.000
# 12                         Grupo Globo   8.636
# 13                               Globo  10.396
# 14                          Ambev Tech   9.740
# 15                               Ambev   9.727
# 16                                Dasa   8.216
# 17                            Ipiranga   6.600
# 18                                 Via  10.483
# ...

# %% [markdown]
# * Criando Funçao

# %%
def busca_salarios_glassdoor(url_glassdoor):

    # A primeira coisa a se fazer é entender o que queremos extrair e qual sua estrutura
    # Para isso, usar o 'Inspecionar' e, no canto superior esquerdo, clicar na setinha com o nome de 'Select an element in the page to inspect it - Ctrl + Shift + C'

    cabecalho = {'user-agent':'Mozilla/5.0'} # Uso de um cabeçalho + Navegador para mostrar que nao somos um Robô

    resposta = requests.get(url_glassdoor, headers = cabecalho) # Extraçao das informaçoes do HTML da página
    soup = resposta.text # Transformaçao das informaçoes para o formato de Texto

    site = BeautifulSoup(soup, 'html.parser') # Convertendo o conteúdo HTML para um Objeto BeautfulSoup

    lista_empresas = site.find_all(
    'h3', 
    {'data-test':re.compile('salaries-list-item-.*-employer-name')} # Busca todas as estruturas
    )

    lista_salarios = site.find_all(
        'div', 
        {'data-test':re.compile('salaries-list-item-.*-salary-info')}
    )

    empresas = []
    salarios = []
    for empresa, salario in zip(lista_empresas, lista_salarios):
        empresas.append(empresa.find('a').text)
        salarios.append(salario.find('h3').text.replace('R$\xa0', ''))

    df = pd.DataFrame(
        {
            'empresa':empresas,
            'salario':salarios
        },
        columns = ['empresa', 'salario']
    )

    return df

print('Cientista de Dados')
display(busca_salarios_glassdoor('https://www.glassdoor.com.br/Sal%C3%A1rios/cientista-de-dados-sal%C3%A1rio-SRCH_KO0,18.htm'))
print()
print()
print()

print('Analista de Dados')
display(busca_salarios_glassdoor('https://www.glassdoor.com.br/Sal%C3%A1rios/analista-de-dados-j%C3%BAnior-sal%C3%A1rio-SRCH_KO0,24.htm'))
print()
print()
print()

print('Engenheiro de Dados')
display(busca_salarios_glassdoor('https://www.glassdoor.com.br/Sal%C3%A1rios/engenheiro-de-dados-pleno-sal%C3%A1rio-SRCH_KO0,25.htm'))
print()
print()
print()
# Out:
# Cientista de Dados
#                                empresa salario
# 0      Itaú Unibanco (Itaú BBA e Rede)  10.346
# 1                                  IBM   5.748
# 2                             Semantix   8.887
# 3   Hospital Israelita Albert Einstein  12.869
# 4                       Banco Bradesco   7.375
# 5                                Propz   7.170
# 6          Radix Engenharia e Software   8.139
# 7                            Stefanini   7.025
# 8                    Autônomo (Brazil)   6.063
# 9                                TOTVS  11.490
# 10                            Softplan  10.566
# 11                              Nubank  12.000
# 12                         Grupo Globo   8.636
# 13                               Globo  10.396
# 14                          Ambev Tech   9.740
# 15                               Ambev   9.727
# 16                                Dasa   8.216
# 17                            Ipiranga   6.600
# ...

# %% [markdown]
# # <font color='red' style='font-size: 40px;'>5.0) Criando uma rotina de scraping </font>

# %%
# Importando bibliotecas
from urllib.request import urlopen, urlretrieve
from bs4 import BeautifulSoup
import pandas as pd

# Declarando variável cards
cards = []

# Obtendo o HTML
response = urlopen('https://alura-site-scraping.herokuapp.com/index.php')
html = response.read().decode('utf-8')
soup = BeautifulSoup(html, 'html.parser')


# Obtendo as TAGs de interesse
anuncios = soup.find('div', {'id': 'container-cards'}).findAll('div', {'class': 'well card'})


# Coletando as informações dos cards
for anuncio in anuncios:
    card = {}
    
    # Valor
    card['value'] = anuncio.find('p', {'class': 'txt-value'}).getText()

    # Informações
    infos = anuncio.find('div', {'class': 'body-card'}).findAll('p')
    for info in infos:
        card[info.get('class')[0].split('-')[-1]] = info.get_text()

    # Acessórios
    items = anuncio.find('div', {'class': 'body-card'}).ul.findAll('li')
    items.pop()
    acessorios = []
    for item in items:
        acessorios.append(item.get_text().replace('► ', ''))
    card['items'] = acessorios

    # Adicionando resultado à lista cards
    cards.append(card)
    
    # Imagens
    image = anuncio.find('div', {'class': 'image-card'}).img
    urlretrieve(image.get('src'), './output/img/' + image.get('src').split('/')[-1])         
    

# Criando um DataFrame com os resultados
dataset = pd.DataFrame(cards)
dataset.to_csv('./output/data/dataset.csv', sep=';', index = False, encoding = 'utf-8-sig')
dataset
# Out:
#         value                    name category            motor  \
# 0  R$ 338.000   LAMBORGHINI AVENTADOR    USADO    Motor 1.8 16v
# 1  R$ 346.000                  BMW M2    USADO    Motor 3.0 32v
# 2  R$ 480.000                    ALFA    USADO    Motor 1.8 16v
# 3  R$ 133.000                   PUECH    USADO  Motor Diesel V8
# 4  R$ 175.000  LAMBORGHINI MURCIELAGO    USADO     Motor 1.0 8v
# 5  R$ 239.000            ASTON MARTIN    USADO  Motor Diesel V6
# 6  R$ 115.000                     TVR    USADO  Motor 4.0 Turbo
# 7  R$ 114.000               EXCALIBUR    USADO    Motor 3.0 32v
# 8   R$ 75.000                 MCLAREN     NOVO     Motor Diesel
# 9  R$ 117.000                  TOYOTA    USADO  Motor 4.0 Turbo
#
#             description             location  \
# 0  Ano 1993 - 55.286 km  Belo Horizonte - MG
# 1  Ano 2018 - 83.447 km  Belo Horizonte - MG
# 2  Ano 2004 - 19.722 km  Rio de Janeiro - RJ
# 3  Ano 1992 - 34.335 km       São Paulo - SP
# ...

# %% [markdown]
# #### Exercícios

# %%
# from bs4 import BeautifulSoup

# teste = """
#     <html>
#         <body>
#             <h1>Fotos</h1>
#             <div>
#                 <img alt="Foto" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/mercedes-benz-slr/mercedes-benz-slr-2925433__340.jpg">
#                 <img alt="Foto" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/vwbeetle/vwbeetle-836065__340.jpg">
#                 <img alt="Foto" src="https://caelum-online-public.s3.amazonaws.com/1381-scraping/01/img-cars/porsche-911-gt2rs/porsche-911-gt2rs-3076518__340.jpg">
#             </div>
#         </body>
#     </html>
# """
# teste_soup = BeautifulSoup(teste, 'html.parser')
# teste_soup

# %%
# for image in teste_soup('img'):
#     print(image.get('src'))

# %% [markdown]
# # <font color=green>7. WEB SCRAPING DO SITE ALURA MOTORS - OBTENDO OS DADOS DE TODOS OS ANÚNCIOS DO SITE

# %% [markdown]
# # 7.1. Identificando as informações no HTML

# %% [markdown]
# #### Agora que sei coletar todas informações de 1 página, preciso fazer para todas as páginas

# %%
soup.find('span', {'class': 'info-pages'}).get_text()
# Out:
# 'Página 1 de 25'

# %%
soup.find('span', {'class': 'info-pages'}).get_text().split()
# Out:
# ['Página', '1', 'de', '25']

# %%
soup.find('span', {'class': 'info-pages'}).get_text().split()[-1] #isso é uma string
# Out:
# '25'

# %%
int(soup.find('span', {'class': 'info-pages'}).get_text().split()[-1]) #transformando para inteiro a fim de iterar
# Out:
# 25

# %% [markdown]
# #### Exercícios

# %%
# from bs4 import BeautifulSoup

# teste_html = """
#     <html>
#         <body>
#             <h1>Busca por veículos</h1>
#             <div>
#                 <p id="info-search">Encontramos 1325 anúncios</p>
#                 <span class="info-pages">20 anúncios por página</span>
#             </div>
#         </body>
#     </html>
# """
# teste_soup = BeautifulSoup(teste_html, 'html.parser')
# teste_soup

# %%
# total_paginas = int(teste_soup.find('p', {'id':'info-search'}).get_text().split()[1])/ int(teste_soup.find('span', {'class':'info-pages'}).get_text().split()[0])

# %%
# import math
# math.ceil(total_paginas)

# %% [markdown]
# # 7.2. Criando uma rotina de scraping

# %%
# Importando bibliotecas
from urllib.request import urlopen, urlretrieve
from bs4 import BeautifulSoup
import pandas as pd

# Declarando variável cards
cards = []

# Obtendo o HTML e o total de páginas
response = urlopen('https://alura-site-scraping.herokuapp.com/index.php')
html = response.read().decode('utf-8')
soup = BeautifulSoup(html, 'html.parser')
pages = int(soup.find('span', {'class': 'info-pages'}).get_text().split()[-1])

# Iterando por todas as páginas do site
for i in range(pages):
    
    #Obtendo o HTML
    response = urlopen('https://alura-site-scraping.herokuapp.com/index.php?page=' + str(i+1))
    html = response.read().decode('utf-8')
    soup = BeautifulSoup(html, 'html.parser')


    ## Obtendo as TAGs de interesse
    anuncios = soup.find('div', {'id': 'container-cards'}).findAll('div', {'class': 'well card'})


    # Coletando as informações dos cards
    for anuncio in anuncios:
        card = {}

        # Valor
        card['value'] = anuncio.find('p', {'class': 'txt-value'}).getText()

        # Informações
        infos = anuncio.find('div', {'class': 'body-card'}).findAll('p')
        for info in infos:
            card[info.get('class')[0].split('-')[-1]] = info.get_text()

        # Acessórios
        items = anuncio.find('div', {'class': 'body-card'}).ul.findAll('li')
        items.pop()
        acessorios = []
        for item in items:
            acessorios.append(item.get_text().replace('► ', ''))
        card['items'] = acessorios

        # Adicionando resultado à lista cards
        cards.append(card)

        # Imagens
        image = anuncio.find('div', {'class': 'image-card'}).img
        urlretrieve(image.get('src'), './output/img/' + image.get('src').split('/')[-1])         
    

# Criando um DataFrame com os resultados
dataset = pd.DataFrame(cards)
dataset.to_csv('./output/data/dataset.csv', sep=';', index = False, encoding = 'utf-8-sig')
dataset
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# c:\Users\leova\Desktop\Repositorio\Resumo_Python\03_Python_WebScrapping.ipynb Célula: 249 in <cell line: 10>()
#       <a href='vscode-notebook-cell:/c%3A/Users/leova/Desktop/Repositorio/Resumo_Python/03_Python_WebScrapping.ipynb#Y532sZmlsZQ%3D%3D?line=6'>7</a> cards = []
#       <a href='vscode-notebook-cell:/c%3A/Users/leova/Desktop/Repositorio/Resumo_Python/03_Python_WebScrapping.ipynb#Y532sZmlsZQ%3D%3D?line=8'>9</a> # Obtendo o HTML e o total de páginas
# ---> <a href='vscode-notebook-cell:/c%3A/Users/leova/Desktop/Repositorio/Resumo_Python/03_Python_WebScrapping.ipynb#Y532sZmlsZQ%3D%3D?line=9'>10</a> response = urlopen('https://alura-site-scraping.herokuapp.com/index.php')
# ...
